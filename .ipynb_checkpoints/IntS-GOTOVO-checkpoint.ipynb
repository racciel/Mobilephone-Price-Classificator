# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
def plot_2d_clf_problem(X, y, h=None):
    assert X.shape[1] == 2, "Dataset nije u dvije dimenzije"

    plt.scatter(X[:,0],X[:,1], c=y, cmap=plt.cm.tab20b, marker='o', s=50)

# %%
file_path1 = "/home/raccielpop/Documents/FAX/FOI/DS/3. semestar/IntS/Projekt/train.csv"
file_path2 = "/home/raccielpop/Documents/FAX/FOI/DS/3. semestar/IntS/Projekt/test.csv"

# %%
data = pd.read_csv(file_path1)

data_test = pd.read_csv(file_path2)

X = np.array(data[['ram', 'battery_power']])
y = np.array(data['price_range'])

X2 = np.array(data_test[['ram', 'battery_power']])

plt.scatter(X[:,0],X[:,1], c=y)
plt.show()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3840)

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

mm = MinMaxScaler()
X_train = mm.fit_transform(X_train)
X_test = mm.transform(X_test)

X2 = mm.fit_transform(X2)

# %% [markdown]
# ### KNN

# %%
from numpy.linalg import norm
from sklearn.metrics import accuracy_score, zero_one_loss

class KNN:
    def __init__(self, n_neighbors=3):
        self.k = n_neighbors
        self.X_train = []
        self.y_train = []

    def fit(self, X_train, y_train):
        if len(X_train) != len(y_train):
            print("X i Y nisu jednakih duljina!")
        self.X_train = X_train
        self.y_train = y_train
        return self

    def predict(self, X_test):
        preds = np.array([])
        for x in X_test:
            dist = norm(self.X_train - x, axis=1)
            ind = np.argsort(dist)
            top = ind[:min(len(ind), self.k)]

            ys = [self.y_train[i] for i in top]
            preds = np.append(preds, max(set(ys), key=ys.count))

        return preds

# %%
custom_knn = KNN(n_neighbors=3)
custom_knn.fit(X_train, y_train)
preds = custom_knn.predict(X_test)

model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)
preds2 = model.predict(X_test)

acc_c = accuracy_score(y_test, preds)
acc_s = accuracy_score(y_test, preds2)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.subplot(1, 2, 2)
plt.scatter(X_test[:, 0], X_test[:, 1], c=preds, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Klasifikacija naše implementacije\nPreciznost: {acc_c:.2f}")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()

preds = custom_knn.predict(X2)
preds2 = model.predict(X2)

plt.figure(figsize=(10, 5))

plt.scatter(X2[:, 0], X2[:, 1], c=preds, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Klasifikacija naše implementacije na testnom izvoru (bez oznaka)")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.show()

plt.figure(figsize=(10, 5))

plt.scatter(X2[:, 0], X2[:, 1], c=preds2, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Klasifikacija ugrađene implementacije na testnom izvoru (bez oznaka)")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.show()

# %%
model = KNeighborsClassifier(algorithm="brute", n_neighbors=3)
model.fit(X_train, y_train)
predictions_sklearn = model.predict(X_test)

accuracy_sklearn = accuracy_score(y_test, predictions_sklearn)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.subplot(1, 2, 2)
plt.scatter(X_test[:, 0], X_test[:, 1], c=predictions_sklearn, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Klasifikacija ugrađene funkcije\nPreciznost: {accuracy_sklearn:.2f}")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

K = list(range(1, 101))

train = []
test = []
for k in K:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    train.append(1 - knn.score(X_train, y_train))
    test.append(1 - knn.score(X_test, y_test))

best_k = K[np.argmin(test)]

plt.plot(K, train, label="Train error")
plt.plot(K, test, label="Test error")
plt.title(f"Najbolji K: {best_k}")
plt.xlabel("RAM")
plt.ylabel("Battery Power")
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

alg = ["auto", "ball_tree", "kd_tree", "brute"]

plt.figure(figsize=(5, 5))

plt.subplot(1, 1, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")
plt.show()

plt.figure(figsize=(10, 10))

for i, a in enumerate(alg):
    model = KNeighborsClassifier(algorithm=a, n_neighbors=3)
    model.fit(X_train, y_train)
    predictions_sklearn = model.predict(X_test)

    accuracy_sklearn = accuracy_score(y_test, predictions_sklearn)

    plt.subplot(2, 2, i+1)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=predictions_sklearn, cmap=plt.cm.tab20b, marker='o', s=50)
    plt.title(f"Metoda: {a}\nPreciznost: {accuracy_sklearn:.2f}")
    plt.xlabel("RAM")
    plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

alg = ["auto", "ball_tree", "kd_tree", "brute"]

plt.figure(figsize=(5, 5))

plt.subplot(1, 1, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")
plt.show()

plt.figure(figsize=(10, 10))

for i, a in enumerate(alg):
    model = KNeighborsClassifier(algorithm=a, n_neighbors=best_k)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    acc = accuracy_score(y_test, preds)

    plt.subplot(2, 2, i+1)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=preds, cmap=plt.cm.tab20b, marker='o', s=50)
    plt.title(f"Metoda: {a}\nPreciznost: {acc:.2f}")
    plt.xlabel("RAM")
    plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

alg = ["auto", "ball_tree", "kd_tree", "brute"]

data_all = np.array(data)

data_all = data_all[:,0:20]

ys = np.array(data)[:,20]

X_tr, X_ts, y_tr, y_ts = train_test_split(data_all, ys, test_size=0.2, random_state=3840)

for i, a in enumerate(alg):
    model = KNeighborsClassifier(algorithm=a, n_neighbors=best_k)
    model.fit(X_tr, y_tr)
    preds = model.predict(X_ts)
    
    acc = accuracy_score(y_ts, preds)
    print(f"Metoda: {a}, preciznost: {acc}")
# Out:
# Metoda: auto, preciznost: 0.9175
# Metoda: ball_tree, preciznost: 0.9175
# Metoda: kd_tree, preciznost: 0.9175
# Metoda: brute, preciznost: 0.9175

# %%
from sklearn.neighbors import KNeighborsClassifier

alg = ["auto", "ball_tree", "kd_tree", "brute"]

data_all = np.array(data[['ram', 'battery_power', 'px_height', 'px_width']])

ys = np.array(data)[:,20]

X_tr, X_ts, y_tr, y_ts = train_test_split(data_all, ys, test_size=0.2, random_state=3840)

for i, a in enumerate(alg):
    model = KNeighborsClassifier(algorithm=a, n_neighbors=best_k)
    model.fit(X_tr, y_tr)
    preds = model.predict(X_ts)
    
    acc = accuracy_score(y_ts, preds)
    print(f"Metoda: {a}, preciznost: {acc}")
# Out:
# Metoda: auto, preciznost: 0.9175
# Metoda: ball_tree, preciznost: 0.9175
# Metoda: kd_tree, preciznost: 0.9175
# Metoda: brute, preciznost: 0.9175

# %% [markdown]
# ### Bayes

# %%
model = GaussianNB()
model.fit(X_train, y_train)

preds = model.predict(X_test)

acc = accuracy_score(y_test, preds)
print(f"Preciznost Bayesa: {acc:.2f}")

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.subplot(1, 2, 2)
plt.scatter(X_test[:, 0], X_test[:, 1], c=preds, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Naivni Bayes\nPreciznost: {acc:.2f}")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()
# Out:
# Preciznost Bayesa: 0.79

# %%
data_all = np.array(data)

data_all = data_all[:,0:20]

ys = np.array(data)[:,20]

X_tr, X_ts, y_tr, y_ts = train_test_split(data_all, ys, test_size=0.2, random_state=3840)

model = GaussianNB()
model.fit(X_tr, y_tr)

preds = model.predict(X_ts)

acc = accuracy_score(y_ts, preds)
print(f"Preciznost Bayesa: {acc:.2f}")
# Out:
# Preciznost Bayesa: 0.82

# %%
data_all = np.array(data[['ram', 'battery_power', 'px_height', 'px_width']])

ys = np.array(data)[:,20]

X_tr, X_ts, y_tr, y_ts = train_test_split(data_all, ys, test_size=0.2, random_state=3840)

model = GaussianNB()
model.fit(X_tr, y_tr)

preds = model.predict(X_ts)

acc = accuracy_score(y_ts, preds)
print(f"Preciznost Bayesa: {acc:.2f}")
# Out:
# Preciznost Bayesa: 0.81

# %%
model = GaussianNB()
model.fit(X_train, y_train)

preds = model.predict(X2)

plt.figure(figsize=(10, 5))

plt.scatter(X2[:, 0], X2[:, 1], c=preds, cmap=plt.cm.tab20b, marker='o', s=50)
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()

# %%
model = GaussianNB()
model.fit(X_train, y_train)

preds = model.predict(X2)

plt.figure(figsize=(10, 5))

plt.subplot(1,2,1)
plt.scatter(X2[:, 0], X2[:, 1], c=preds, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Naivni Bayes na skupu bez oznaka:")
plt.xlabel("RAM")
plt.ylabel("Battery Power")


model = KNeighborsClassifier(n_neighbors=10)
model.fit(X_train, y_train)

preds2 = model.predict(X2)


plt.subplot(1,2,2)
plt.scatter(X2[:,0], X2[:,1], c=preds2)
plt.title("KNN na skupu bez oznaka (k=10):")
plt.xlabel("RAM")
plt.ylabel("Battery Power")


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Neuronska mreža

# %%
# !pip install tensorflow-cpu
# Out:
# Collecting tensorflow-cpu
#   Downloading tensorflow_cpu-2.18.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (3.3.0)
# Requirement already satisfied: packaging in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (2.31.0)
# Requirement already satisfied: setuptools in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (61.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (1.60.0)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-cpu)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-cpu)
#   Downloading keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (1.26.4)
# Collecting h5py>=3.11.0 (from tensorflow-cpu)
#   Downloading h5py-3.12.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorflow-cpu) (0.35.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-cpu) (0.37.1)
# Requirement already satisfied: rich in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow-cpu) (13.3.4)
# Requirement already satisfied: namex in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow-cpu) (0.0.8)
# Requirement already satisfied: optree in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from keras>=3.5.0->tensorflow-cpu) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2022.9.24)
# Requirement already satisfied: markdown>=2.6.8 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow-cpu) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow-cpu) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from tensorboard<2.19,>=2.18->tensorflow-cpu) (2.2.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-cpu) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-cpu) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from rich->keras>=3.5.0->tensorflow-cpu) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from rich->keras>=3.5.0->tensorflow-cpu) (2.15.1)
# Requirement already satisfied: zipp>=0.5 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-cpu) (3.10.0)
# Requirement already satisfied: mdurl~=0.1 in /home/raccielpop/miniconda3/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.5.0->tensorflow-cpu) (0.1.2)
# Downloading tensorflow_cpu-2.18.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (230.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:00:03m
# Downloading h5py-3.12.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 16.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 20.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# Installing collected packages: h5py, tensorboard, keras, tensorflow-cpu
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.10.0
#     Uninstalling h5py-3.10.0:
#       Successfully uninstalled h5py-3.10.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.0
#     Uninstalling tensorboard-2.17.0:
#       Successfully uninstalled tensorboard-2.17.0
#   Attempting uninstall: keras
#     Found existing installation: keras 3.4.1
#     Uninstalling keras-3.4.1:
#       Successfully uninstalled keras-3.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.0 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.18.0 which is incompatible.
# Successfully installed h5py-3.12.1 keras-3.6.0 tensorboard-2.18.0 tensorflow-cpu-2.18.0
#
# [notice] A new release of pip is available: 24.1.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-11-09 11:41:54.175370: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-09 11:41:54.291255: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-09 11:41:54.326861: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-09 11:41:54.532851: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-09 11:41:56.131566: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
ss = StandardScaler()
X_train_s = ss.fit_transform(X_train)
X_test_s = ss.transform(X_test)

y_train_encoded = to_categorical(y_train)
y_test_encoded = to_categorical(y_test)

model = Sequential()
model.add(Dense(16, input_dim=2, activation='sigmoid'))
model.add(Dense(4, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_s, y_train_encoded, epochs=50, validation_data=(X_test_s, y_test_encoded), verbose=1)

_, accuracy = model.evaluate(X_test_s, y_test_encoded)
print(f"Preciznost mreže: {accuracy:.2f}")

plt.plot(history.history['accuracy'], label='Treninranje')
plt.plot(history.history['val_accuracy'], label='Testiranje')
plt.title('Preciznost treniranja i testiranja')
plt.xlabel('Epoha')
plt.ylabel('Preciznost')
plt.legend()
plt.show()

preds = model.predict(X_test_s)
#print(preds)
preds_classes = np.argmax(preds, axis=1)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.subplot(1, 2, 2)
plt.scatter(X_test[:, 0], X_test[:, 1], c=preds_classes, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Neuronska mreža\nPreciznost: {history.history['val_accuracy'][len(history.history['val_accuracy'])-1]:.2f}")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()
# Out:
# /home/raccielpop/miniconda3/lib/python3.9/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731148917.972395   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.220600   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.220833   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.222150   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.222408   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.222584   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.303877   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.304161   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1731148918.304375   13735 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-11-09 11:41:58.304503: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3492 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731148919.216602   13800 service.cc:146] XLA service 0x73d08c002040 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731148919.216640   13800 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce GTX 1050, Compute Capability 6.1
# 2024-11-09 11:41:59.273324: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-09 11:41:59.495480: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8902
# 2024-11-09 11:41:59.543141: W external/local_xla/xla/stream_executor/gpu/redzone_allocator_kernel_cuda.cc:136] NOT_FOUND: Couldn't find a suitable version of ptxas. The following locations were considered: ./cuda_sdk_lib/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /home/raccielpop/.local/share/pnpm/ptxas, /home/raccielpop/software/des/ptxas, /home/raccielpop/miniconda3/bin/ptxas, /home/raccielpop/miniconda3/condabin/ptxas, /usr/local/sbin/ptxas, /usr/local/bin/ptxas, /usr/sbin/ptxas, /usr/bin/ptxas, /sbin/ptxas, /bin/ptxas, /usr/games/ptxas, /usr/local/games/ptxas, /snap/bin/ptxas, /snap/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /usr/local/cuda-12.3/bin/ptxas, /usr/local/cuda/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc/bin/ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-11-09 11:42:00.075905: W tensorflow/core/framework/op_kernel.cc:1840] OP_REQUIRES failed at xla_ops.cc:577 : NOT_FOUND: Couldn't find a suitable version of ptxas. The following locations were considered: ./cuda_sdk_lib/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /home/raccielpop/.local/share/pnpm/ptxas, /home/raccielpop/software/des/ptxas, /home/raccielpop/miniconda3/bin/ptxas, /home/raccielpop/miniconda3/condabin/ptxas, /usr/local/sbin/ptxas, /usr/local/bin/ptxas, /usr/sbin/ptxas, /usr/bin/ptxas, /sbin/ptxas, /bin/ptxas, /usr/games/ptxas, /usr/local/games/ptxas, /snap/bin/ptxas, /snap/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /usr/local/cuda-12.3/bin/ptxas, /usr/local/cuda/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc/bin/ptxas
# 2024-11-09 11:42:00.075947: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: NOT_FOUND: Couldn't find a suitable version of ptxas. The following locations were considered: ./cuda_sdk_lib/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /home/raccielpop/.local/share/pnpm/ptxas, /home/raccielpop/software/des/ptxas, /home/raccielpop/miniconda3/bin/ptxas, /home/raccielpop/miniconda3/condabin/ptxas, /usr/local/sbin/ptxas, /usr/local/bin/ptxas, /usr/sbin/ptxas, /usr/bin/ptxas, /sbin/ptxas, /bin/ptxas, /usr/games/ptxas, /usr/local/games/ptxas, /snap/bin/ptxas, /snap/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /usr/local/cuda-12.3/bin/ptxas, /usr/local/cuda/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc/bin/ptxas
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[20], line 14
#      10 model.add(Dense(4, activation='softmax'))
#      12 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# ---> 14 history = model.fit(X_train_s, y_train_encoded, epochs=50, validation_data=(X_test_s, y_test_encoded), verbose=1)
#      16 _, accuracy = model.evaluate(X_test_s, y_test_encoded)
#      17 print(f"Preciznost mreže: {accuracy:.2f}")
#
# File ~/miniconda3/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/home/raccielpop/miniconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 736, in start
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#
#   File "/tmp/ipykernel_13735/1168875676.py", line 14, in <module>
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 318, in fit
#
#   File "/home/raccielpop/miniconda3/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 121, in one_step_on_iterator
#
# Couldn't find a suitable version of ptxas. The following locations were considered: ./cuda_sdk_lib/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /home/raccielpop/.local/share/pnpm/ptxas, /home/raccielpop/software/des/ptxas, /home/raccielpop/miniconda3/bin/ptxas, /home/raccielpop/miniconda3/condabin/ptxas, /usr/local/sbin/ptxas, /usr/local/bin/ptxas, /usr/sbin/ptxas, /usr/bin/ptxas, /sbin/ptxas, /bin/ptxas, /usr/games/ptxas, /usr/local/games/ptxas, /snap/bin/ptxas, /snap/bin/ptxas, /home/raccielpop/software/exist-db/bin/ptxas, /home/raccielpop/software/Flora-2/flora2/ptxas, /home/raccielpop/software/Flora-2/XSB/bin/ptxas, /home/raccielpop/software/godot/ptxas, /usr/local/cuda-12.3/bin/ptxas, /usr/local/cuda/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas, /home/raccielpop/miniconda3/lib/python3.9/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc/bin/ptxas
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_one_step_on_iterator_1009]

# %%
model = Sequential()
model.add(Dense(16, input_dim=2, activation='sigmoid'))
model.add(Dense(4, activation='sigmoid'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_s, y_train_encoded, epochs=50, validation_data=(X_test_s, y_test_encoded), verbose=1)

_, accuracy = model.evaluate(X_test_s, y_test_encoded)
print(f"Preciznost mreže: {accuracy:.2f}")

plt.plot(history.history['accuracy'], label='Treniranje')
plt.plot(history.history['val_accuracy'], label='Testiranje')
plt.title('Preciznost treniranja i testiranja')
plt.xlabel('Epoha')
plt.ylabel('Preciznost')
plt.legend()
plt.show()

preds = model.predict(X_test_s)
preds_classes = np.argmax(preds, axis=1)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.subplot(1, 2, 2)
plt.scatter(X_test[:, 0], X_test[:, 1], c=preds_classes, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Neuronska mreža\nPreciznost: {history.history['val_accuracy'][len(history.history['val_accuracy'])-1]:.2f}")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()

# %%
model = Sequential()
model.add(Dense(8, input_dim=2, activation='sigmoid'))
model.add(Dense(4, activation='sigmoid'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_s, y_train_encoded, epochs=50, validation_data=(X_test_s, y_test_encoded), verbose=1)

_, accuracy = model.evaluate(X_test_s, y_test_encoded)
print(f"Preciznost mreže: {accuracy:.2f}")

plt.plot(history.history['accuracy'], label='Preciznost treniranja')
plt.plot(history.history['val_accuracy'], label='Preciznost testiranja')
plt.title('Preciznost treniranja i testiranja')
plt.xlabel('Epoha')
plt.ylabel('Preciznost')
plt.legend()
plt.show()

preds = model.predict(X_test_s)
#print(preds)
preds_classes = np.argmax(preds, axis=1)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title("Stvarna klasifikacija")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.subplot(1, 2, 2)
plt.scatter(X_test[:, 0], X_test[:, 1], c=preds_classes, cmap=plt.cm.tab20b, marker='o', s=50)
plt.title(f"Neuronska mreža\nPreciznost: {history.history['val_accuracy'][len(history.history['val_accuracy'])-1]:.2f}")
plt.xlabel("RAM")
plt.ylabel("Battery Power")

plt.tight_layout()
plt.show()
